# %%
pip install numpy==1.19.2
# Out:
# Requirement already satisfied: numpy==1.19.2 in c:\users\pc\anaconda3\lib\site-packages (1.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy

# %%
print(numpy.__version__)
# Out:
# 1.19.2

# %%
pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\pc\anaconda3\lib\site-packages (0.0.49)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Flask>=1.1.2 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (4.47.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (3.12.2)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (2.4.1)
# Requirement already satisfied: keras>=2.2.0 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (2.4.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (1.19.2)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (0.1.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (1.0.5)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (7.2.0)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\pc\anaconda3\lib\site-packages (from deepface) (4.5.1.48)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\pc\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\pc\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\pc\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\pc\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Requirement already satisfied: six in c:\users\pc\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: filelock in c:\users\pc\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: requests[socks] in c:\users\pc\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.24.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.12.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.13.0)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.2)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
#
# Requirement already satisfied: tensorboard~=2.4 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.4.1)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.4.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.3.3)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.32.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: pyyaml in c:\users\pc\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\pc\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (1.5.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\pc\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\pc\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\pc\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pc\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pc\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pc\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\pc\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: setuptools in c:\users\pc\anaconda3\lib\site-packages (from protobuf>=3.9.2->tensorflow>=1.9.0->deepface) (49.2.0.post20200714)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.28.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.8.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pc\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pc\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\pc\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (4.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pc\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pc\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.8)

# %%
from deepface import DeepFace

# %%
import matplotlib.pyplot as plt

# %%
pip install --user opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\pc\appdata\roaming\python\python38\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\pc\anaconda3\lib\site-packages (from opencv-contrib-python) (1.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
img1 = cv2.imread("C:\\Users\\PC\\Desktop\\musk1.jpg")

# %%
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
img2 = cv2.imread("C:\\Users\\PC\\Desktop\\musk2.jpg")
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
result = DeepFace.verify(img1, img2)

# %%
print("face matched: ", result["verified"])
